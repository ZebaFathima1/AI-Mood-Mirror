# %%
# !where python
# Out:
# c:\Users\ZEBA FATHIMA\.conda\envs\faceai\python.exe

# %%
# !pip install deepface opencv-python pandas
# Out:
# Requirement already satisfied: deepface in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (0.0.83)
# Requirement already satisfied: opencv-python in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (4.12.0.88)
# Requirement already satisfied: pandas in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (11.3.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (3.1.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (23.0.0)
# Collecting numpy>=1.14.0 (from deepface)
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: termcolor in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from fire>=0.4.0->deepface) (3.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (8.7.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: colorama in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from click>=8.1.3->Flask>=1.1.2->deepface) (0.4.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (4.13.4)
# Requirement already satisfied: filelock in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: requests[socks] in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (2.32.5)
# Requirement already satisfied: packaging in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gunicorn>=20.1.0->deepface) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow>=1.9.0->deepface)
#   Downloading protobuf-3.19.6-cp39-cp39-win_amd64.whl.metadata (807 bytes)
# Requirement already satisfied: setuptools in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (78.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.74.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/15.9 MB 11.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/15.9 MB 8.7 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/15.9 MB 8.6 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.9 MB 9.3 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.9 MB 9.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/15.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/15.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/15.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/15.9 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.5/15.9 MB 9.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/15.9 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/15.9 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/15.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 5.3 MB/s eta 0:00:00
# Downloading protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
#    ---------------------------------------- 0.0/895.9 kB ? eta -:--:--
#    ---------------------------------------- 895.9/895.9 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: protobuf, numpy
#
#   Attempting uninstall: protobuf
#
#     Found existing installation: protobuf 3.20.3
#
#     Uninstalling protobuf-3.20.3:
#
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#       Successfully uninstalled protobuf-3.20.3
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#    ---------------------------------------- 0/2 [protobuf]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/2 [protobuf]
#     Found existing installation: numpy 1.24.3
#    ---------------------------------------- 0/2 [protobuf]
#    -------------------- ------------------- 1/2 [numpy]
#     Uninstalling numpy-1.24.3:
#    -------------------- ------------------- 1/2 [numpy]
#       Successfully uninstalled numpy-1.24.3
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    -------------------- ------------------- 1/2 [numpy]
#    ---------------------------------------- 2/2 [numpy]
#
# Successfully installed numpy-2.0.2 protobuf-3.19.6
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ZEBA FATHIMA\.conda\envs\faceai\Lib\site-packages\google\~-otobuf'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ZEBA FATHIMA\.conda\envs\faceai\Lib\site-packages\~~mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.48.1 requires protobuf<7,>=3.20, but you have protobuf 3.19.6 which is incompatible.

# %%
# !pip install numpy==1.24.3 --force-reinstall
# Out:
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.3-cp39-cp39-win_amd64.whl (14.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Successfully installed numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# streamlit 1.48.1 requires protobuf<7,>=3.20, but you have protobuf 3.19.6 which is incompatible.

# %%
# !pip install deepface opencv-python-headless pandas pillow
# Out:
# Requirement already satisfied: deepface in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (0.0.83)
# Requirement already satisfied: opencv-python-headless in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (4.12.0.88)
# Requirement already satisfied: pandas in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (2.3.2)
# Requirement already satisfied: pillow in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (11.3.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (4.67.1)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (4.12.0.88)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (3.1.1)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from deepface) (23.0.0)
# Collecting numpy>=1.14.0 (from deepface)
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: termcolor in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from fire>=0.4.0->deepface) (3.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (8.7.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: colorama in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from click>=8.1.3->Flask>=1.1.2->deepface) (0.4.6)
# Requirement already satisfied: beautifulsoup4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (4.13.4)
# Requirement already satisfied: filelock in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (3.18.0)
# Requirement already satisfied: requests[socks] in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gdown>=3.10.1->deepface) (2.32.5)
# Requirement already satisfied: packaging in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gunicorn>=20.1.0->deepface) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (78.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.74.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.3.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Successfully installed numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.48.1 requires protobuf<7,>=3.20, but you have protobuf 3.19.6 which is incompatible.

# %%
# !pip install numpy==1.24.3 matplotlib==3.7.2
# Out:
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib==3.7.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.2) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.2) (1.17.0)
# Using cached numpy-1.24.3-cp39-cp39-win_amd64.whl (14.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# streamlit 1.48.1 requires protobuf<7,>=3.20, but you have protobuf 3.19.6 which is incompatible.

# %%
# !pip uninstall matplotlib -y
# Out:
# Found existing installation: matplotlib 3.7.2
# Uninstalling matplotlib-3.7.2:
#   Successfully uninstalled matplotlib-3.7.2

# %%
# !pip install matplotlib==3.7.2
# Out:
# Collecting matplotlib==3.7.2
#   Downloading matplotlib-3.7.2-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from matplotlib==3.7.2) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.2) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.2) (1.17.0)
# Downloading matplotlib-3.7.2-cp39-cp39-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ------------ --------------------------- 2.4/7.5 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.5 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: matplotlib
# Successfully installed matplotlib-3.7.2

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("✅ Matplotlib is working!")
plt.show()
# Out:
# c:\Users\ZEBA FATHIMA\.conda\envs\faceai\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import os
print("📂 Current working directory:", os.getcwd())
# Out:
# 📂 Current working directory: c:\Users\ZEBA FATHIMA\lstemo

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (1.48.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (11.3.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.32.1-cp39-cp39-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: colorama in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in c:\users\zeba fathima\.conda\envs\faceai\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading protobuf-6.32.1-cp39-cp39-win_amd64.whl (435 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed protobuf-6.32.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 6.32.1 which is incompatible.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 6.32.1 which is incompatible.

# %%
import os

os.makedirs(".streamlit", exist_ok=True)
with open(".streamlit/config.toml", "w") as f:
    f.write("""
[theme]
primaryColor = "#FF4B4B"
backgroundColor = "#1E1E1E"
secondaryBackgroundColor = "#31333F"
textColor = "#FAFAFA"
font = "sans serif"
""")

# %%
app_code = '''
import streamlit as st
import cv2
from deepface import DeepFace
import os
from datetime import datetime
import pandas as pd
from PIL import Image

# ------------------ Theme ------------------
st.set_page_config(page_title="AI Mood Mirror", layout="centered")

st.markdown(
    """
    <style>
    .title {
        font-size:40px;
        font-weight:700;
        color:#ff4b4b;
        text-align:center;
        margin-bottom:10px;
    }
    .subtitle {
        text-align:center;
        color:gray;
        font-size:18px;
    }
    .emoji-box {
        font-size:60px;
        text-align:center;
        margin-top:20px;
    }
    .msg {
        font-size:20px;
        font-weight:500;
        text-align:center;
        color:#4CAF50;
    }
    </style>
    """,
    unsafe_allow_html=True
)

# ------------------ Header ------------------
st.markdown("<div class='title'>🪞 AI Mood Mirror</div>", unsafe_allow_html=True)
st.markdown("<div class='subtitle'>Let AI reflect your vibe today!</div>", unsafe_allow_html=True)
st.markdown("---")

# ------------------ Emoji Map ------------------
emoji_map = {
    'happy': ('😄', 'Cheer up! You’re glowing! 🌟'),
    'sad': ('😢', 'Hey, everything will be okay 💖'),
    'angry': ('😠', 'Breathe. You’ve got this! 💪'),
    'neutral': ('😐', 'Stay calm and centered. 🧘‍♀️'),
    'surprise': ('😮', 'Wow! What happened?! 🎉'),
    'fear': ('😨', 'Fear is temporary, power is permanent! ⚡'),
    'disgust': ('🤢', 'Shake it off! New vibe incoming 🚀'),
}

# ------------------ Webcam Button ------------------
start = st.button("📸 Capture Emotion from Webcam")

if start:
    st.info("Get ready! Capturing in 3 seconds...")
    cap = cv2.VideoCapture(0)

    for i in range(3, 0, -1):
        st.write(f"⏳ Capturing in {i}...")
        cv2.waitKey(1000)

    ret, frame = cap.read()
    img_path = "captured.jpg"
    cv2.imwrite(img_path, frame)
    cap.release()
    cv2.destroyAllWindows()

    st.success("📸 Image captured!")
    st.image(Image.open(img_path), caption="Captured Image", use_container_width=True)

    try:
        result = DeepFace.analyze(img_path=img_path, actions=["emotion"], enforce_detection=False)
        emotion = result[0]['dominant_emotion']
        emoji, message = emoji_map.get(emotion, ('✨', 'Be your best self today! 💫'))

        st.markdown(f"<div class='emoji-box'>{emoji}</div>", unsafe_allow_html=True)
        st.markdown(f"<div class='msg'>🧠 Detected Emotion: <strong>{emotion.upper()}</strong><br>{message}</div>", unsafe_allow_html=True)

        # Save to CSV silently
        log_entry = {
            "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            "Detected Emotion": emotion
        }

        log_path = "emotion_log.csv"
        if not os.path.exists(log_path):
            pd.DataFrame([log_entry]).to_csv(log_path, index=False)
        else:
            df = pd.read_csv(log_path)
            df = pd.concat([df, pd.DataFrame([log_entry])], ignore_index=True)
            df.to_csv(log_path, index=False)

    except Exception as e:
        st.error(f"❌ Error: {e}")
'''

# ✅ Save to app.py with encoding for emojis
with open("app.py", "w", encoding="utf-8") as f:
    f.write(app_code)

print("✅ Streamlit app written to app.py (with hidden emotion log display)")
# Out:
# ✅ Streamlit app written to app.py (with hidden emotion log display)

# %%
streamlit run app.py
# Out:
#   Cell In[16], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax

# %%
with open("requirements.txt", "w") as f:
    f.write("streamlit\ndeepface\nopencv-python\npillow\npandas")
